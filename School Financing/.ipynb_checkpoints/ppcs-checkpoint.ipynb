# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path="ppcs_2012_2016.csv"
ppcs_df=pd.read_csv(csv_path)
ppcs_df.head()
# Out:
#    Year       State      PPCS
# 0  2016     Alabama   9236.42
# 1  2016      Alaska  17509.98
# 2  2016     Arizona   7613.01
# 3  2016    Arkansas   9845.57
# 4  2016  California  11495.33

# %%
states_list=ppcs_df["State"].unique().tolist()
state_dfs={state:ppcs_df.loc[(ppcs_df["State"] == state),:] for state in states_list}
state_dfs["Alaska"]
# Out:
#      Year   State      PPCS
# 1    2016  Alaska  17509.98
# 52   2015  Alaska  20172.49
# 103  2014  Alaska  18415.91
# 154  2013  Alaska  18175.00
# 205  2012  Alaska  17390.40

# %%
x_axis=ppcs_df["Year"].unique().tolist()
x_axis
# Out:
# [2016, 2015, 2014, 2013, 2012]

# %%
no_mj_states=["Idaho","Wyoming","South Dakota","Nebraska", "Texas", "Kansas", "Iowa","Wisconsin","Indiana","Kentucky","Tennessee","Virginia","North Carolina","South Carolina","Georgia", "Alabama","Mississippi"]
no_mj_states_df=ppcs_df.loc[(ppcs_df["State"].isin(no_mj_states)),:]
no_mj_states_df
# Out:
#      Year           State      PPCS
# 0    2016         Alabama   9236.42
# 10   2016         Georgia   9768.71
# 12   2016           Idaho   7157.40
# 14   2016         Indiana   9856.31
# 15   2016            Iowa  11150.21
# 16   2016          Kansas   9959.64
# 17   2016        Kentucky   9862.91
# 24   2016     Mississippi   8701.85
# 27   2016        Nebraska  12298.90
# 33   2016  North Carolina   8792.05
# 40   2016  South Carolina  10249.07
# 41   2016    South Dakota   9175.74
# 42   2016       Tennessee   8809.82
# 43   2016           Texas   9015.87
# 46   2016        Virginia  11432.34
# 49   2016       Wisconsin  11456.00
# 50   2016         Wyoming  16441.98
# 51   2015         Alabama   9127.93
# 61   2015         Georgia   9427.28
# 63   2015           Idaho   6923.09
# 65   2015         Indiana   9686.79
# 66   2015            Iowa  10943.96
# 67   2015          Kansas  10039.87
# 68   2015        Kentucky   9630.42
# 75   2015     Mississippi   8455.67
# 78   2015        Nebraska  11945.58
# 84   2015  North Carolina   8687.22
# 91   2015  South Carolina   9953.13
# 92   2015    South Dakota   8937.02
# 93   2015       Tennessee   8723.37
# ..    ...             ...       ...
# 168  2013            Iowa  10312.92
# 169  2013          Kansas   9827.80
# 170  2013        Kentucky   9315.90
# 177  2013     Mississippi   8130.33
# 180  2013        Nebraska  11579.27
# 186  2013  North Carolina   8390.15
# 193  2013  South Carolina   9513.61
# 194  2013    South Dakota   8469.80
# 195  2013       Tennessee   8495.53
# 196  2013           Texas   8298.91
# 199  2013        Virginia  10959.85
# 202  2013       Wisconsin  11070.85
# 203  2013         Wyoming  15699.62
# 204  2012         Alabama   8562.06
# 214  2012         Georgia   9247.02
# 216  2012           Idaho   6658.57
# 218  2012         Indiana   9719.10
# 219  2012            Iowa  10038.28
# 220  2012          Kansas   9748.05
# 221  2012        Kentucky   9391.18
# 228  2012     Mississippi   8164.24
# 231  2012        Nebraska  11274.84
# 237  2012  North Carolina   8200.32
# 244  2012  South Carolina   9147.18
# 245  2012    South Dakota   8446.36
# 246  2012       Tennessee   8294.44
# 247  2012           Texas   8260.66
# 250  2012        Virginia  10655.91
# 253  2012       Wisconsin  11041.66
# 254  2012         Wyoming  15897.00
#
# [85 rows x 3 columns]

# %%
no_mj_states_groupby_year=no_mj_states_df.groupby("Year")
no_mj_avg_ppcs=no_mj_states_groupby_year.mean()
no_mj_avg_ppcs
# Out:
#               PPCS
# Year
# 2012   9573.345294
# 2013   9663.230588
# 2014   9800.752353
# 2015  10000.514706
# 2016  10197.954118

# %%
no_mj_ppcs,= plt.plot(x_axis, no_mj_avg_ppcs["PPCS"], label="Non-Legal States", color="red")
colorado_ppcs,= plt.plot(x_axis, state_dfs["Colorado"]["PPCS"], label="Colorado", color="green")
washington_ppcs,= plt.plot(x_axis, state_dfs["Washington"]["PPCS"], label="Washington", color="teal")

plt.legend()
plt.show()
