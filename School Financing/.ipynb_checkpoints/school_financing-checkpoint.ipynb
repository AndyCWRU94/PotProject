# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# original dataframe
csv_path="school_financing_2012_2016.csv"
finance_df=pd.read_csv(csv_path).sort_values(["Year","State"])
finance_df.head()
# Out:
#      Year       State  Total Revenue  Revenue from federal sources  \
# 204  2012     Alabama      7135105.0                      789954.0
# 205  2012      Alaska      2383402.0                      352005.0
# 206  2012     Arizona      7869244.0                     1050228.0
# 207  2012    Arkansas      5151611.0                      666267.0
# 208  2012  California     66568626.0                     8793325.0
#
#      Revenue from state sources  Revenue from local sources  \
# 204                   3948651.0                   2396500.0
# 205                   1507913.0                    523484.0
# 206                   2845535.0                   3973481.0
# 207                   3823172.0                    662172.0
# 208                  36413273.0                  21362028.0
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 204           7212701.0         6493448.0        580949.0            138304.0
# ...

# %%
# creating a new "per pupil" dataframe by dividing all columns by # of enrolled students
finance_pp_df=finance_df[["Year","State"]]
key_list=finance_df.keys().tolist()
key_list.remove("Year")
key_list.remove("State")
key_list.remove("Enrollment")
key_list.remove("Population (thousands)")
for key in key_list:
    column=finance_df.loc[:,key]/finance_df.loc[:,"Enrollment"]
    finance_pp_df.loc[:,key]=column.values
finance_pp_df.sort_values(["Year","State"]).head()
# Out:
#      Year       State  Total Revenue  Revenue from federal sources  \
# 204  2012     Alabama       9.582197                      1.060881
# 205  2012      Alaska      18.225769                      2.691767
# 206  2012     Arizona       8.347223                      1.114019
# 207  2012    Arkansas      10.830198                      1.400689
# 208  2012  California      10.731624                      1.417585
#
#      Revenue from state sources  Revenue from local sources  \
# 204                    5.302900                    3.218416
# 205                   11.530943                    4.003059
# 206                    3.018373                    4.214831
# 207                    8.037429                    1.392080
# 208                    5.870236                    3.443803
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 204            9.686406          8.720474        0.780194            0.185737
# ...

# %%
#loop creating a dictionary of dataframes for each state. 
#call each state's dataframe using state_pp_dfs["state name"]
states_pp_list=finance_pp_df["State"].unique().tolist()
state_pp_dfs={state:finance_pp_df.loc[(finance_pp_df["State"] == state),:] 
              for state in states_list}
state_pp_dfs["Colorado"]
# Out:
#      Year     State  Total Revenue  Revenue from federal sources  \
# 209  2012  Colorado      10.164966                      0.836932
# 158  2013  Colorado      10.319164                      0.818113
# 107  2014  Colorado      10.537688                      0.787339
# 56   2015  Colorado      11.009565                      0.819945
# 5    2016  Colorado      11.426949                      0.810641
#
#      Revenue from state sources  Revenue from local sources  \
# 209                    4.391340                    4.936693
# 158                    4.340253                    5.160798
# 107                    4.578799                    5.171550
# 56                     4.991889                    5.197731
# 5                      4.956430                    5.659878
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 209            9.991884          8.634387        0.827206            0.530291
# ...

# %%
#creating a new dataframe of only states with no legalized marijuana
no_mj_states=["Idaho","Wyoming","South Dakota","Nebraska", "Texas", "Kansas", "Iowa","Wisconsin","Indiana","Kentucky","Tennessee","Virginia","North Carolina","South Carolina","Georgia", "Alabama","Mississippi"]
no_mj_states_pp_df=finance_pp_df.loc[(finance_pp_df["State"].isin(no_mj_states)),:]
no_mj_states_pp_df.head()
# Out:
#      Year    State  Total Revenue  Revenue from federal sources  \
# 204  2012  Alabama       9.582197                      1.060881
# 214  2012  Georgia      10.517926                      1.115712
# 216  2012    Idaho       7.404850                      0.994510
# 218  2012  Indiana      12.062616                      1.089681
# 219  2012     Iowa      12.162996                      1.033025
#
#      Revenue from state sources  Revenue from local sources  \
# 204                    5.302900                    3.218416
# 214                    4.466417                    4.935797
# 216                    4.630765                    1.779575
# 218                    7.413465                    3.559470
# 219                    5.406730                    5.723242
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 204            9.686406          8.720474        0.780194            0.185737
# ...

# %%
#groupby dataframe of states with no MJ by year, then visualize groupby using mean
no_mj_states_pp_groupby_year=no_mj_states_pp_df.groupby("Year")
no_mj_pp_df=no_mj_states_pp_groupby_year.mean()
no_mj_pp_df
# Out:
#       Total Revenue  Revenue from federal sources  Revenue from state sources  \
# Year
# 2012      11.003582                      1.223029                    5.219903
# 2013      11.017431                      1.106821                    5.382665
# 2014      11.238038                      1.061290                    5.532719
# 2015      11.618675                      1.093017                    5.849974
# 2016      11.933976                      1.092259                    6.013047
#
#       Revenue from local sources  Total expenditures  Current spending  \
# Year
# 2012                    4.560650           10.997012          9.647991
# 2013                    4.527945           11.039603          9.738551
# 2014                    4.644030           11.241041          9.877642
# 2015                    4.675683           11.633035         10.080034
# 2016                    4.828669           11.955700         10.280216
#
# ...

# %%
#create dataframe for national averages
national_pp_groupby_year=finance_pp_df.groupby("Year")
national_pp_averages=national_pp_groupby_year.mean()
national_pp_averages
# Out:
#       Total Revenue  Revenue from federal sources  Revenue from state sources  \
# Year
# 2012      12.949873                      1.310714                    6.189286
# 2013      13.010423                      1.194739                    6.329778
# 2014      13.417690                      1.155345                    6.663563
# 2015      13.871311                      1.181804                    6.945825
# 2016      14.160523                      1.179245                    7.096612
#
#       Revenue from local sources  Total expenditures  Current spending  \
# Year
# 2012                    5.571231           12.823223         11.374975
# 2013                    5.610020           12.969382         11.537529
# 2014                    5.729440           13.266452         11.797752
# 2015                    5.879874           13.747592         12.181167
# 2016                    6.023814           14.042302         12.406296
#
# ...

# %%
x_axis=finance_df["Year"].astype("int32").unique().tolist()
x_axis
# Out:
# [2012, 2013, 2014, 2015, 2016]

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Total Revenue"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Total Revenue"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Total Revenue"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Total Revenue"], label="National Avg", color='grey')
plt.legend()
plt.title("Total Revenue Per Pupil")
plt.savefig('total_revenue_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Revenue from federal sources"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Revenue from federal sources"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Revenue from federal sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Revenue from federal sources"], label="National Avg", color='grey')
plt.legend()
plt.title("Revenue from federal sources Per Pupil")
plt.savefig('federal_revenue_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Revenue from state sources"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Revenue from state sources"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Revenue from state sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Revenue from state sources"], label="National Avg", color='grey')
plt.legend()
plt.title("Revenue from state sources Per Pupil")
plt.savefig('state_revenue_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Revenue from local sources"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Revenue from local sources"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Revenue from local sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Revenue from local sources"], label="National Avg", color='grey')
plt.legend()
plt.title("Revenue from local sources Per Pupil")
plt.savefig('local_revenue_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Total expenditures"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Total expenditures"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Total expenditures"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Total expenditures"], label="National Avg", color='grey')
plt.legend()
plt.title("Total Expenditures Per Pupil")
plt.savefig('total_expenditures_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Current spending"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Current spending"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Current spending"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Current spending"], label="National Avg", color='grey')
plt.legend()
plt.title("Current Spending Per Pupil")
plt.savefig('current_spending_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Capital outlay"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Capital outlay"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Capital outlay"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Capital outlay"], label="National Avg", color='grey')
plt.legend()
plt.title("Capital Outlay Per Pupil")
plt.savefig('capital_outlay_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Other expenditures"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Other expenditures"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Other expenditures"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Other expenditures"], label="National Avg", color='grey')
plt.legend()
plt.title("Other Expenditures Per Pupil")
plt.savefig('other_expenditures_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Outstanding Debt"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Outstanding Debt"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Outstanding Debt"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Outstanding Debt"], label="National Avg", color='grey')
plt.legend()
plt.title("Outstanding Debt Per Pupil")
plt.savefig('outstanding_debt_pp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_pp_dfs["Colorado"]["Cash and securities"], label="Colorado", color='green')
plt.plot(x_axis, state_pp_dfs["Washington"]["Cash and securities"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_pp_df["Cash and securities"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_pp_averages["Cash and securities"], label="National Avg", color='grey')
plt.legend()
plt.title("Cash and Securities Per Pupil")
plt.savefig('cash_securities_pp.png', bbox_inches='tight')
plt.show()

# %%
states_list=finance_df["State"].unique().tolist()
state_dfs={state:finance_df.loc[(finance_df["State"] == state),:] for state in states_list}
state_dfs["Alaska"]
# Out:
#      Year   State  Total Revenue  Revenue from federal sources  \
# 205  2012  Alaska      2383402.0                      352005.0
# 154  2013  Alaska      2545076.0                      320938.0
# 103  2014  Alaska      2663488.0                      309525.0
# 52   2015  Alaska      2920866.0                      344111.0
# 1    2016  Alaska      2494680.0                      307320.0
#
#      Revenue from state sources  Revenue from local sources  \
# 205                   1507913.0                    523484.0
# 154                   1707449.0                    516689.0
# 103                   1824373.0                    529590.0
# 52                    2026555.0                    550200.0
# 1                     1613675.0                    573685.0
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 205           2483320.0         2285517.0        145219.0             52584.0
# ...

# %%
no_mj_states=["Idaho","Wyoming","South Dakota","Nebraska", "Texas", "Kansas", "Iowa","Wisconsin","Indiana","Kentucky","Tennessee","Virginia","North Carolina","South Carolina","Georgia", "Alabama","Mississippi"]
no_mj_states_df=finance_df.loc[(finance_df["State"].isin(no_mj_states)),:]
no_mj_states_df
# Out:
#      Year           State  Total Revenue  Revenue from federal sources  \
# 204  2012         Alabama      7135105.0                      789954.0
# 214  2012         Georgia     17556060.0                     1862297.0
# 216  2012           Idaho      1981212.0                      266087.0
# 218  2012         Indiana     12142555.0                     1096902.0
# 219  2012            Iowa      6031265.0                      512246.0
# 220  2012          Kansas      5612118.0                      410051.0
# 221  2012        Kentucky      7191188.0                      983232.0
# 228  2012     Mississippi      4466518.0                      795110.0
# 231  2012        Nebraska      3691601.0                      366016.0
# 237  2012  North Carolina     12788659.0                     1831015.0
# 244  2012  South Carolina      7875144.0                      848254.0
# 245  2012    South Dakota      1296353.0                      212615.0
# ...

# %%
no_mj_states_groupby_year=no_mj_states_df.groupby("Year")
no_mj_df=no_mj_states_groupby_year.mean()
no_mj_df
# Out:
#       Total Revenue  Revenue from federal sources  Revenue from state sources  \
# Year
# 2012   1.022038e+07                  1.164095e+06                4.699718e+06
# 2013   1.024320e+07                  1.068077e+06                4.788060e+06
# 2014   1.058402e+07                  1.039310e+06                4.969887e+06
# 2015   1.094237e+07                  1.066003e+06                5.170195e+06
# 2016   1.130890e+07                  1.073214e+06                5.329593e+06
#
#       Revenue from local sources  Total expenditures  Current spending  \
# Year
# 2012                4.356565e+06        1.022495e+07      8.847672e+06
# 2013                4.387059e+06        1.032751e+07      8.976091e+06
# 2014                4.574824e+06        1.058450e+07      9.186043e+06
# 2015                4.706169e+06        1.100035e+07      9.462799e+06
# 2016                4.906090e+06        1.137527e+07      9.677421e+06
#
# ...

# %%
national_groupby_year=finance_df.groupby("Year")
national_averages=national_groupby_year.mean()
national_averages
# Out:
#       Total Revenue  Revenue from federal sources  Revenue from state sources  \
# Year
# 2012   1.165736e+07                  1.167298e+06                  5408639.18
# 2013   1.172028e+07                  1.066444e+06                  5476051.18
# 2014   1.211874e+07                  1.037290e+06                  5776724.02
# 2015   1.257627e+07                  1.045243e+06                  6028515.44
# 2016   1.315587e+07                  1.061579e+06                  6359126.44
#
#       Revenue from local sources  Total expenditures  Current spending  \
# Year
# 2012                5.187478e+06        1.163656e+07      1.026588e+07
# 2013                5.285163e+06        1.172319e+07      1.042497e+07
# 2014                5.417991e+06        1.203367e+07      1.071946e+07
# 2015                5.620720e+06        1.253573e+07      1.113125e+07
# 2016                5.859855e+06        1.303323e+07      1.150990e+07
#
# ...

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Total Revenue"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Total Revenue"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Total Revenue"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Total Revenue"], label="National Avg", color="grey")
plt.legend()
plt.title("Total Revenue")
plt.savefig('total_revenue.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Revenue from federal sources"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Revenue from federal sources"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Revenue from federal sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Revenue from federal sources"], label="National Avg", color="grey")
plt.legend()
plt.title("Revenue from federal sources")
plt.savefig('federal_revenue.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Revenue from state sources"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Revenue from state sources"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Revenue from state sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Revenue from state sources"], label="National Avg", color="grey")
plt.legend()
plt.title("Revenue from state sources")
plt.savefig('state_revenue.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Revenue from local sources"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Revenue from local sources"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Revenue from local sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Revenue from local sources"], label="National Avg", color="grey")
plt.legend()
plt.title("Revenue from local sources")
plt.savefig('local_revenue.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Total expenditures"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Total expenditures"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Total expenditures"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Total expenditures"], label="National Avg", color="grey")
plt.legend()
plt.title("Total expenditures")
plt.savefig('total_expenditures.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Current spending"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Current spending"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Current spending"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Current spending"], label="National Avg", color="grey")
plt.legend()
plt.title("Current spending")
plt.savefig('current_spending.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Capital outlay"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Capital outlay"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Capital outlay"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Capital outlay"], label="National Avg", color="grey")
plt.legend()
plt.title("Capital outlay")
plt.savefig('capital_outlay.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Other expenditures"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Other expenditures"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Other expenditures"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Other expenditures"], label="National Avg", color="grey")
plt.legend()
plt.title("Other expenditures")
plt.savefig('other_expenditures.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Outstanding Debt"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Outstanding Debt"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Outstanding Debt"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Outstanding Debt"], label="National Avg", color="grey")
plt.legend()
plt.title("Outstanding Debt")
plt.savefig('outstanding_debt.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Cash and securities"], label="Colorado", color="green")
plt.plot(x_axis, state_dfs["Washington"]["Cash and securities"], label="Washington", color="teal")
plt.plot(x_axis, no_mj_df["Cash and securities"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Cash and securities"], label="National Avg", color="grey")
plt.legend()
plt.title("Cash and securities")
plt.savefig('cash_securities.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Enrollment"], label="Colorado", color='green')
plt.plot(x_axis, state_dfs["Washington"]["Enrollment"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_df["Enrollment"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Enrollment"], label="National Avg", color='grey')
plt.legend()
plt.title("Enrollment")
plt.savefig('enrollment.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_dfs["Colorado"]["Population (thousands)"], label="Colorado", color='green')
plt.plot(x_axis, state_dfs["Washington"]["Population (thousands)"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_df["Population (thousands)"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_averages["Population (thousands)"], label="National Avg", color='grey')
plt.legend()
plt.title("Population (thousands)")
plt.savefig('population.png', bbox_inches='tight')
plt.show()

# %%
# creating a new "per thousand people" dataframe by dividing all columns by population (thousands)

finance_ptp_df=finance_df[["Year","State"]]
key_list=finance_df.keys().tolist()
key_list.remove("Year")
key_list.remove("State")
key_list.remove("Population (thousands)")
for key in key_list:
    column=finance_df.loc[:,key]/finance_df.loc[:,"Population (thousands)"]
    finance_ptp_df.loc[:,key]=column.values
finance_ptp_df.sort_values(["Year","State"]).head()
# Out:
#      Year       State  Total Revenue  Revenue from federal sources  \
# 204  2012     Alabama    1479.698258                    163.822895
# 205  2012      Alaska    3260.467852                    481.538988
# 206  2012     Arizona    1200.861285                    160.266748
# 207  2012    Arkansas    1746.900983                    225.929807
# 208  2012  California    1749.917878                    231.153887
#
#      Revenue from state sources  Revenue from local sources  \
# 204                  818.882414                  496.992949
# 205                 2062.808482                  716.120383
# 206                  434.233939                  606.360598
# 207                 1296.429976                  224.541200
# 208                  957.211246                  561.552746
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 204         1495.790336       1346.629614      120.478847           28.681875
# ...

# %%
#loop creating a dictionary of dataframes for each state. call state's dataframe using state_pp_dfs["state name"]
states_list=finance_df["State"].unique().tolist()
states_ptp_list=finance_ptp_df["State"].unique().tolist()
state_ptp_dfs={state:finance_ptp_df.loc[(finance_ptp_df["State"] == state),:] for state in states_list}
state_ptp_dfs["Colorado"]
# Out:
#      Year     State  Total Revenue  Revenue from federal sources  \
# 209  2012  Colorado    1651.944102                    136.012722
# 158  2013  Colorado    1665.830615                    132.068665
# 107  2014  Colorado    1702.302838                    127.190067
# 56   2015  Colorado    1762.500275                    131.263351
# 5    2016  Colorado    1819.794394                    129.098373
#
#      Revenue from state sources  Revenue from local sources  \
# 209                  713.652082                  802.279298
# 158                  700.650417                  833.111533
# 107                  739.678678                  835.434093
# 56                   799.142044                  832.094880
# 5                    789.334358                  901.361664
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 209         1623.815921       1403.204318      134.432151           86.179453
# ...

# %%
#creating a new dataframe of only states with no legalized marijuana
no_mj_states=["Idaho","Wyoming","South Dakota","Nebraska", "Texas", "Kansas", "Iowa","Wisconsin","Indiana","Kentucky","Tennessee","Virginia","North Carolina","South Carolina","Georgia", "Alabama","Mississippi"]
no_mj_states_ptp_df=finance_ptp_df.loc[(finance_ptp_df["State"].isin(no_mj_states)),:]
no_mj_states_ptp_df.head()
# Out:
#      Year    State  Total Revenue  Revenue from federal sources  \
# 204  2012  Alabama    1479.698258                    163.822895
# 214  2012  Georgia    1769.764113                    187.731552
# 216  2012    Idaho    1241.360902                    166.721178
# 218  2012  Indiana    1857.511856                    167.798990
# 219  2012     Iowa    1962.025049                    166.638256
#
#      Revenue from state sources  Revenue from local sources  \
# 204                  818.882414                  496.992949
# 214                  751.526915                  830.505645
# 216                  776.308897                  298.330827
# 218                 1141.593086                  548.119780
# 219                  872.164932                  923.221861
#
#      Total expenditures  Current spending  Capital outlay  Other expenditures  \
# 204         1495.790336       1346.629614      120.478847           28.681875
# ...

# %%
#groupby dataframe of states with no MJ by year, then visualize groupby using mean
no_mj_states_ptp_groupby_year=no_mj_states_ptp_df.groupby("Year")
no_mj_ptp_df=no_mj_states_ptp_groupby_year.mean()
no_mj_ptp_df
# Out:
#       Total Revenue  Revenue from federal sources  Revenue from state sources  \
# Year
# 2012    1752.257754                    194.848740                  830.227866
# 2013    1752.300060                    176.297170                  854.297859
# 2014    1787.762601                    168.882493                  878.678211
# 2015    1847.521943                    173.758016                  928.577368
# 2016    1893.568420                    173.129074                  952.207690
#
#       Revenue from local sources  Total expenditures  Current spending  \
# Year
# 2012                  727.181147         1751.262657       1535.086579
# 2013                  721.705031         1755.790338       1547.699098
# 2014                  740.201897         1788.479751       1569.951062
# 2015                  745.186560         1849.851965       1600.679163
# 2016                  768.231656         1897.182528       1628.341066
#
# ...

# %%
#create dataframe for national averages
national_ptp_groupby_year=finance_ptp_df.groupby("Year")
national_ptp_averages=national_ptp_groupby_year.mean()
national_ptp_averages
# Out:
#       Total Revenue  Revenue from federal sources  Revenue from state sources  \
# Year
# 2012    1905.562223                    194.310371                  934.633763
# 2013    1905.176716                    176.157869                  952.794609
# 2014    1955.761987                    169.333682                  998.033845
# 2015    1989.622776                    170.345251                 1022.173645
# 2016    2056.017131                    171.634213                 1054.205527
#
#       Revenue from local sources  Total expenditures  Current spending  \
# Year
# 2012                  794.944242         1892.390704       1681.232120
# 2013                  794.906486         1900.108670       1695.791822
# 2014                  807.963750         1935.918058       1727.116888
# 2015                  817.146500         1974.013870       1753.502844
# 2016                  850.848087         2041.135046       1803.557720
#
# ...

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Total Revenue"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Total Revenue"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Total Revenue"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Total Revenue"], label="National Avg", color='grey')
plt.legend()
plt.title("Total Revenue Per Thousand People")
plt.savefig('total_revenue_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Revenue from federal sources"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Revenue from federal sources"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Revenue from federal sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Revenue from federal sources"], label="National Avg", color='grey')
plt.legend()
plt.title("Revenue from federal sources Per Thousand People")
plt.savefig('federal_revenue_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Revenue from state sources"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Revenue from state sources"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Revenue from state sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Revenue from state sources"], label="National Avg", color='grey')
plt.legend()
plt.title("Revenue from state sources Per Thousand People")
plt.savefig('state_revenue_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Revenue from local sources"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Revenue from local sources"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Revenue from local sources"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Revenue from local sources"], label="National Avg", color='grey')
plt.legend()
plt.title("Revenue from local sources Per Thousand People")
plt.savefig('local_revenue_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Total expenditures"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Total expenditures"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Total expenditures"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Total expenditures"], label="National Avg", color='grey')
plt.legend()
plt.title("Total Expenditures Per Thousand People")
plt.savefig('total_expenditures_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Current spending"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Current spending"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Current spending"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Current spending"], label="National Avg", color='grey')
plt.legend()
plt.title("Current Spending Per Thousand People")
plt.savefig('current_spending_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Capital outlay"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Capital outlay"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Capital outlay"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Capital outlay"], label="National Avg", color='grey')
plt.legend()
plt.title("Capital Outlay Per Thousand People")
plt.savefig('capital_outlay_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Other expenditures"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Other expenditures"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Other expenditures"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Other expenditures"], label="National Avg", color='grey')
plt.legend()
plt.title("Other Expenditures Per Thousand People")
plt.savefig('other_expenditures_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Outstanding Debt"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Outstanding Debt"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Outstanding Debt"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Outstanding Debt"], label="National Avg", color='grey')
plt.legend()
plt.title("Outstanding Debt Per Thousand People")
plt.savefig('outstanding_debt_ptp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_axis, state_ptp_dfs["Colorado"]["Cash and securities"], label="Colorado", color='green')
plt.plot(x_axis, state_ptp_dfs["Washington"]["Cash and securities"], label="Washington", color='teal')
plt.plot(x_axis, no_mj_ptp_df["Cash and securities"], label="Non-Legal States", color='red')
plt.plot(x_axis, national_ptp_averages["Cash and securities"], label="National Avg", color='grey')
plt.legend()
plt.title("Cash and Securities Per Pupil")
plt.savefig('cash_securities_ptp.png', bbox_inches='tight')
plt.show()
