# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

opioid_file_2012 = "Opioid raw_data (2012).csv"

opioid_data_2012 = pd.read_csv(opioid_file_2012)

# %%
opioid_data_2012.head()
# Out:
#         Location Opioid Overdose Death Rate (Age-Adjusted)  \
# 0  United States                                       7.4
# 1        Alabama                                       3.6
# 2         Alaska                                      10.8
# 3        Arizona                                       8.2
# 4       Arkansas                                         6
#
#    All Drug Overdose Death Rate (Age-Adjusted)  \
# 0                                         13.1
# 1                                         12.1
# 2                                         17.4
# 3                                         17.7
# 4                                         13.1
#
#   Percent Change in Opioid Overdose Death Rate from Prior Year  \
# 0                                              0.014
# 1                                             -0.053
# 2                                              0.241
# 3                                             -0.068
# ...

# %%
opioid_df_2012 = opioid_data_2012.dropna()
opioid_df_2012.head()
# Out:
#         Location Opioid Overdose Death Rate (Age-Adjusted)  \
# 0  United States                                       7.4
# 1        Alabama                                       3.6
# 2         Alaska                                      10.8
# 3        Arizona                                       8.2
# 4       Arkansas                                         6
#
#    All Drug Overdose Death Rate (Age-Adjusted)  \
# 0                                         13.1
# 1                                         12.1
# 2                                         17.4
# 3                                         17.7
# 4                                         13.1
#
#   Percent Change in Opioid Overdose Death Rate from Prior Year  \
# 0                                              0.014
# 1                                             -0.053
# 2                                              0.241
# 3                                             -0.068
# ...

# %%
op_df_2012 = opioid_df_2012.set_index("Location")
op_df_2012.head()
# Out:
#               Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                       7.4
# Alabama                                             3.6
# Alaska                                             10.8
# Arizona                                             8.2
# Arkansas                                              6
#
#                All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                         13.1
# Alabama                                               12.1
# Alaska                                                17.4
# Arizona                                               17.7
# Arkansas                                              13.1
#
#               Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# United States                                              0.014
# Alabama                                                   -0.053
# ...

# %%
op_df_2012_st = op_df_2012.loc[["United States","Arizona", "Colorado", "Florida", "Washington"]]

# %%
op_df_2012_st
# Out:
#               Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                       7.4
# Arizona                                             8.2
# Colorado                                            7.7
# Florida                                             6.9
# Washington                                          9.7
#
#                All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                         13.1
# Arizona                                               17.7
# Colorado                                              15.0
# Florida                                               13.3
# Washington                                            13.7
#
#               Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# United States                                              0.014
# Arizona                                                   -0.068
# ...
