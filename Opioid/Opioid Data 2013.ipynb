# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

opioid_file_2013 = "Opioid raw_data (2013).csv"

opioid_data_2013 = pd.read_csv(opioid_file_2013)

# %%
opioid_data_2013.head()
# Out:
#         Location Opioid Overdose Death Rate (Age-Adjusted)  \
# 0  United States                                       7.9
# 1        Alabama                                       3.5
# 2         Alaska                                       9.2
# 3        Arizona                                       8.2
# 4       Arkansas                                       5.6
#
#    All Drug Overdose Death Rate (Age-Adjusted)  \
# 0                                         13.8
# 1                                         12.7
# 2                                         14.4
# 3                                         18.7
# 4                                         11.1
#
#   Percent Change in Opioid Overdose Death Rate from Prior Year  \
# 0                                               0.07
# 1                                              -0.03
# 2                                              -0.15
# 3                                                  0
# ...

# %%
opioid_df_2013 = opioid_data_2013.dropna()
opioid_df_2013.head()
# Out:
#         Location Opioid Overdose Death Rate (Age-Adjusted)  \
# 0  United States                                       7.9
# 1        Alabama                                       3.5
# 2         Alaska                                       9.2
# 3        Arizona                                       8.2
# 4       Arkansas                                       5.6
#
#    All Drug Overdose Death Rate (Age-Adjusted)  \
# 0                                         13.8
# 1                                         12.7
# 2                                         14.4
# 3                                         18.7
# 4                                         11.1
#
#   Percent Change in Opioid Overdose Death Rate from Prior Year  \
# 0                                               0.07
# 1                                              -0.03
# 2                                              -0.15
# 3                                                  0
# ...

# %%
op_df_2013 = opioid_df_2013.set_index("Location")
op_df_2013.head()
# Out:
#               Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                       7.9
# Alabama                                             3.5
# Alaska                                              9.2
# Arizona                                             8.2
# Arkansas                                            5.6
#
#                All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                         13.8
# Alabama                                               12.7
# Alaska                                                14.4
# Arizona                                               18.7
# Arkansas                                              11.1
#
#               Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# United States                                               0.07
# Alabama                                                    -0.03
# ...

# %%
op_df_2013_st = op_df_2013.loc[["United States","Arizona", "Colorado", "Florida", "Washington"]]

# %%
op_df_2013_st
# Out:
#               Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                       7.9
# Arizona                                             8.2
# Colorado                                              8
# Florida                                             6.6
# Washington                                          8.9
#
#                All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                         13.8
# Arizona                                               18.7
# Colorado                                              15.5
# Florida                                               12.6
# Washington                                            13.4
#
#               Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# United States                                               0.07
# Arizona                                                        0
# ...

# %%
op_df_2013_st[["Opioid Overdose Death Rate (Age-Adjusted)","Percent Change in Opioid Overdose Death Rate from Prior Year"]]
# Out:
#               Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                       7.9
# Arizona                                             8.2
# Colorado                                              8
# Florida                                             6.6
# Washington                                          8.9
#
#               Percent Change in Opioid Overdose Death Rate from Prior Year
# Location
# United States                                               0.07
# Arizona                                                        0
# Colorado                                                    0.04
# Florida                                                    -0.04
# Washington                                                 -0.08
